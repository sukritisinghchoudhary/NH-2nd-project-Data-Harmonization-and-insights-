# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import skew

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Load Dataset 1
df1 = pd.read_excel('dataset_1.xlsx')

# %%
df1
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %% [markdown]
# Here I am Inspecting and exploring the data structures using .info() and .head(). so that we can get the inspected dataset-1

# %%
#Inspect Dataset 1

print("Dataset 1 Info:")
df1.info()

print("\nDataset 1 Head:")
print(df1.head())
# Out:
# Dataset 1 Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB
#
# Dataset 1 Head:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# ...

# %%
#Checking for missing values in Dataset 1

print("Missing Values in Dataset 1:")
print(df1.isnull().sum())
# Out:
# Missing Values in Dataset 1:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %% [markdown]
# NOTE : So here we get there is no missing values or we can say null values.

# %%
# Checking for duplicate records in Dataset 1

print("Duplicate Records in Dataset 1:")
print(df1.duplicated().sum())
# Out:
# Duplicate Records in Dataset 1:
# 0

# %% [markdown]
# So I found there is no duplicates as well

# %%
# Checking for data types in Dataset 1

print("Data Types in Dataset 1:")
print(df1.dtypes)
# Out:
# Data Types in Dataset 1:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# dtype: object

# %%
# Load Dataset 2
df2 = pd.read_excel('dataset_2.xlsx')

# %%
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
# Here I am Inspecting Dataset 2 using .info() and .head(). 

print("\nDataset 2 Info:")
df2.info()
print("\nDataset 2 Head:")
print(df2.head())
# Out:
# Dataset 2 Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.2 KB
#
# Dataset 2 Head:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# ...

# %%
# Checking for missing values in Dataset 2

print("\nMissing Values in Dataset 2:")
print(df2.isnull().sum())
# Out:
# Missing Values in Dataset 2:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %% [markdown]
# NOTE : So here I get there is null value in 'atemp'. For that I will will fill that values with the help of (median) .
#        Here I have calculated the median value of the 'atemp' and then replaced that value with null value.

# %%
# I am calculating the value of median 
df2["atemp"].median()
# Out:
# 0.197

# %%
# Checking for duplicate records in Dataset 2

print("\nDuplicate Records in Dataset 2:")
print(df2.duplicated().sum())
# Out:
# Duplicate Records in Dataset 2:
# 0

# %%
# Check data types in Dataset 2

print("\nData Types in Dataset 2:")
print(df2.dtypes)
# Out:
# Data Types in Dataset 2:
# Unnamed: 0      int64
# instant         int64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
# Impute missing values in the 'atemp' column with median.

df2["atemp"] = df2["atemp"].replace(np.nan,0.197)

# %%
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df2.head(25)
# Out:
#     Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0            0        1  0.2879  0.81     0.0000       3          13   16
# 1            1        2  0.2727  0.80     0.0000       8          32   40
# 2            2        3  0.2727  0.80     0.0000       5          27   32
# 3            3        4  0.2879  0.75     0.0000       3          10   13
# 4            4        5  0.2879  0.75     0.0000       0           1    1
# 5            5        6  0.2576  0.75     0.0896       0           1    1
# 6            6        7  0.2727  0.80     0.0000       2           0    2
# 7            7        8  0.2576  0.86     0.0000       1           2    3
# 8            8        9  0.1970  0.75     0.0000       1           7    8
# 9            9       10  0.3485  0.76     0.0000       8           6   14
# 10          10       11  0.3939  0.76     0.2537      12          24   36
# 11          11       12  0.3333  0.81     0.2836      26          30   56
# ...

# %% [markdown]
# NOTE : So here as we can see that the null value of (atemp) filled with median.

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0    0
# instant       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# NOTE : Now as we can see there no null values in 'atemp'

# %%
#here i am deleting the 'Unnamed: 0' column and rename some columns in the data set

#While deleting the column, we can also use'inplace=true'but it is for permanent deletion

# %%
df2= df2.drop(columns=['Unnamed: 0'], errors='ignore').drop_duplicates()

# %%
df2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %% [markdown]
# NOTE : Now here we get corrected data of dataset-2.

# %%
# Get column names
columns_df1 = set(df1.columns)
columns_df2 = set(df2.columns)

# Find common keys
common_keys = columns_df1.intersection(columns_df2)
print("Common Keys:", common_keys)
# Out:
# Common Keys: {'instant'}

# %%
# Merge datasets on common keys 'instant'.
merged_data = pd.merge(df1, df2, on='instant', how='inner')

# %%
merged_data
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %%
#We have correct spelling of the some column spelling was incorrect

merged_data.rename(columns={"dteday":"date","mnth":"month","weathersit":"weather_sit","windspeed":"wind_speed","cnt":"counts"})
# Out:
#      instant       date  season  yr  month  hr  holiday  weekday  weather_sit  \
# 0          1 2011-01-01       1   0      1   0    False        6            1
# 1          2 2011-01-01       1   0      1   1    False        6            1
# 2          3 2011-01-01       1   0      1   2    False        6            1
# 3          4 2011-01-01       1   0      1   3    False        6            1
# 4          5 2011-01-01       1   0      1   4    False        6            1
# ..       ...        ...     ...  ..    ...  ..      ...      ...          ...
# 605      606 2011-01-28       1   0      1  11    False        5            3
# 606      607 2011-01-28       1   0      1  12    False        5            3
# 607      608 2011-01-28       1   0      1  13    False        5            3
# 608      609 2011-01-28       1   0      1  14    False        5            3
# 609      610 2011-01-28       1   0      1  15    False        5            2
#
# ...

# %%
merged_data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
merged_data.drop('yr', axis=1 , inplace = True)

# %%
merged_data
# Out:
#      instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0          1 2011-01-01       1     1   0    False        6           1  0.24
# 1          2 2011-01-01       1     1   1    False        6           1  0.22
# 2          3 2011-01-01       1     1   2    False        6           1  0.22
# 3          4 2011-01-01       1     1   3    False        6           1  0.24
# 4          5 2011-01-01       1     1   4    False        6           1  0.24
# ..       ...        ...     ...   ...  ..      ...      ...         ...   ...
# 605      606 2011-01-28       1     1  11    False        5           3  0.18
# 606      607 2011-01-28       1     1  12    False        5           3  0.18
# 607      608 2011-01-28       1     1  13    False        5           3  0.18
# 608      609 2011-01-28       1     1  14    False        5           3  0.22
# 609      610 2011-01-28       1     1  15    False        5           2  0.20
#
# ...

# %%
merged_data.head(20)
# Out:
#     instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0         1 2011-01-01       1     1   0    False        6           1  0.24
# 1         2 2011-01-01       1     1   1    False        6           1  0.22
# 2         3 2011-01-01       1     1   2    False        6           1  0.22
# 3         4 2011-01-01       1     1   3    False        6           1  0.24
# 4         5 2011-01-01       1     1   4    False        6           1  0.24
# 5         6 2011-01-01       1     1   5    False        6           2  0.24
# 6         7 2011-01-01       1     1   6    False        6           1  0.22
# 7         8 2011-01-01       1     1   7    False        6           1  0.20
# 8         9 2011-01-01       1     1   8    False        6           1  0.24
# 9        10 2011-01-01       1     1   9    False        6           1  0.32
# 10       11 2011-01-01       1     1  10    False        6           1  0.38
# ...

# %%
# Now here I am loading the dataset_3 in to the python.

# %%
# Load Dataset 1
df3 = pd.read_excel('dataset_3.xlsx')

# %%
df3
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
df3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df3.drop('yr', axis=1 , inplace = True)

# %%
df3
# Out:
#      instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        620 2011-01-29       1     1   1    False        6           1  0.22
# 1        621 2011-01-29       1     1   2    False        6           1  0.22
# 2        622 2011-01-29       1     1   3    False        6           1  0.20
# 3        623 2011-01-29       1     1   4    False        6           1  0.16
# 4        624 2011-01-29       1     1   6    False        6           1  0.16
# ..       ...        ...     ...   ...  ..      ...      ...         ...   ...
# 385      615 2011-01-28       1     1  20    False        5           2  0.24
# 386      616 2011-01-28       1     1  21    False        5           2  0.22
# 387      617 2011-01-28       1     1  22    False        5           1  0.24
# 388      618 2011-01-28       1     1  23    False        5           1  0.24
# 389      619 2011-01-29       1     1   0    False        6           1  0.22
#
# ...

# %%
merged_data.columns
# Out:
# Index(['instant', 'dteday', 'season', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['instant', 'dteday', 'season', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
# here concatenate the data after cleanning all the datasets merged_data & dataset_3 (df3).

final_data = pd.concat([merged_data, df3], ignore_index=True,sort=False)

# %%
final_data
# Out:
#      instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0          1 2011-01-01       1     1   0    False        6           1  0.24
# 1          2 2011-01-01       1     1   1    False        6           1  0.22
# 2          3 2011-01-01       1     1   2    False        6           1  0.22
# 3          4 2011-01-01       1     1   3    False        6           1  0.24
# 4          5 2011-01-01       1     1   4    False        6           1  0.24
# ..       ...        ...     ...   ...  ..      ...      ...         ...   ...
# 995      615 2011-01-28       1     1  20    False        5           2  0.24
# 996      616 2011-01-28       1     1  21    False        5           2  0.22
# 997      617 2011-01-28       1     1  22    False        5           1  0.24
# 998      618 2011-01-28       1     1  23    False        5           1  0.24
# 999      619 2011-01-29       1     1   0    False        6           1  0.22
#
# ...

# %% [markdown]
# # Find Final Data in csv format

# %%
final_data.to_csv('final-data.csv', index=False)

# %%
final_data = pd.read_csv('final-data.csv')

# %%
final_data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
final_data.duplicated().sum()
# Out:
# 0

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1000 non-null   int64
#  1   dteday      1000 non-null   object
#  2   season      1000 non-null   int64
#  3   mnth        1000 non-null   int64
#  4   hr          1000 non-null   int64
#  5   holiday     1000 non-null   bool
#  6   weekday     1000 non-null   int64
#  7   weathersit  1000 non-null   int64
#  8   temp        1000 non-null   float64
#  9   atemp       1000 non-null   float64
#  10  hum         1000 non-null   float64
#  11  windspeed   1000 non-null   float64
#  12  casual      1000 non-null   int64
#  13  registered  1000 non-null   int64
#  14  cnt         1000 non-null   int64
# dtypes: bool(1), float64(4), int64(9), object(1)
# memory usage: 110.5+ KB

# %%
final_data.describe()
# Out:
#            instant  season         mnth           hr      weekday  \
# count  1000.000000  1000.0  1000.000000  1000.000000  1000.000000
# mean    500.500000     1.0     1.312000    11.753000     2.982000
# std     288.819436     0.0     0.463542     6.899101     2.091423
# min       1.000000     1.0     1.000000     0.000000     0.000000
# 25%     250.750000     1.0     1.000000     6.000000     1.000000
# 50%     500.500000     1.0     1.000000    12.000000     3.000000
# 75%     750.250000     1.0     2.000000    18.000000     5.000000
# max    1000.000000     1.0     2.000000    23.000000     6.000000
#
#         weathersit         temp        atemp          hum    windspeed  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.480000     0.205900     0.211793     0.582480     0.194931
# std       0.651171     0.078977     0.076295     0.187977     0.129126
# min       1.000000     0.020000     0.000000     0.210000     0.000000
# ...

# %%
final_data
# Out:
#      instant      dteday  season  mnth  hr  holiday  weekday  weathersit  \
# 0          1  2011-01-01       1     1   0    False        6           1
# 1          2  2011-01-01       1     1   1    False        6           1
# 2          3  2011-01-01       1     1   2    False        6           1
# 3          4  2011-01-01       1     1   3    False        6           1
# 4          5  2011-01-01       1     1   4    False        6           1
# ..       ...         ...     ...   ...  ..      ...      ...         ...
# 995      615  2011-01-28       1     1  20    False        5           2
# 996      616  2011-01-28       1     1  21    False        5           2
# 997      617  2011-01-28       1     1  22    False        5           1
# 998      618  2011-01-28       1     1  23    False        5           1
# 999      619  2011-01-29       1     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# NOTE : So here this is FINAL_DATA which is cleaned . Now we are going to do further process with the Final_Data.

# %%
final_data['dteday'] = pd.to_datetime(final_data['dteday'])

# %% [markdown]
# Here we have convert the dteday of the dteday because the datatype of the dteday column is showing the object, so we have to changed it to datetimes.

# %%
# Display basic information about the dataset

final_data.info(), final_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1000 non-null   int64
#  1   dteday      1000 non-null   datetime64[ns]
#  2   season      1000 non-null   int64
#  3   mnth        1000 non-null   int64
#  4   hr          1000 non-null   int64
#  5   holiday     1000 non-null   bool
#  6   weekday     1000 non-null   int64
#  7   weathersit  1000 non-null   int64
#  8   temp        1000 non-null   float64
#  9   atemp       1000 non-null   float64
#  10  hum         1000 non-null   float64
#  11  windspeed   1000 non-null   float64
#  12  casual      1000 non-null   int64
#  13  registered  1000 non-null   int64
#  14  cnt         1000 non-null   int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(9)
# memory usage: 110.5 KB
# (None,
#     instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# ...

# %%
# Checking for missing values in all columns.

#  Missing Value Analysis

missing_values = final_data.isnull().sum()
missing_percentage = (missing_values / len(final_data)) * 100

missing_summary = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percentage
})

missing_summary = missing_summary[missing_summary['Missing Values'] > 0]
missing_summary
# Out:
# Empty DataFrame
# Columns: [Missing Values, Percentage (%)]
# Index: []

# %% [markdown]
# The Final dataset has no missing values in any column so now we are going further to deduct outliers .

# %%
# Outlier Detection - Identify numeric columns

numeric_columns =final_data.select_dtypes(include=['float64', 'int64']).columns
num_cols = len(numeric_columns)

# %%
numeric_columns
# Out:
# Index(['instant', 'season', 'mnth', 'hr', 'weekday', 'weathersit', 'temp',
#        'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(final_data['cnt'])

plt.subplot(1,2,2)
sns.distplot(final_data['hr'])
plt.show()

fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(10,6))
sns.boxplot(data=final_data[['cnt']],ax=ax1)
sns.boxplot(data=final_data[['hr']],ax=ax2)
# Out:
# <Axes: >

# %%
final_data['cnt'].describe()
# Out:
# count    1000.000000
# mean       58.304000
# std        50.985558
# min         1.000000
# 25%        16.000000
# 50%        49.000000
# 75%        83.000000
# max       249.000000
# Name: cnt, dtype: float64

# %%
final_data['cnt'].skew()
# Out:
# 1.1377091237001284

# %%
print("Mean value of count",final_data["cnt"].mean())
print("std deviation of count",final_data["cnt"].std())
# Out:
# Mean value of count 58.304
# std deviation of count 50.9855578679994

# %%
Q1 = final_data['cnt'].quantile(0.25)
Q3 = final_data['cnt'].quantile(0.75)
IQR = Q3-Q1
upper_limit = Q3 + 1.5*IQR
lower_limit = Q1 - 1.5*IQR

print(Q1)
print(Q3)
print(IQR)
print(upper_limit)
print(lower_limit)
# Out:
# 16.0
# 83.0
# 67.0
# 183.5
# -84.5

# %%
final_data["cnt"]=np.where(
    final_data["cnt"]>upper_limit,
    upper_limit,
    np.where(
        final_data["cnt"]<lower_limit,
                         lower_limit,
        final_data["cnt"]))

# %%
sns.boxplot(x=final_data['cnt'])
# Out:
# <Axes: xlabel='cnt'>

# %% [markdown]
# # Box Plot

# %%
# Visualize distributions and detect outliers using boxplots 

plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(4, 4, i)
    sns.boxplot(final_data[col])
    plt.title(f"Boxplot of {col}")
plt.tight_layout()
plt.show()

# %%
# Now we are detecting statistical outlier detection using IQR

outlier_summary = {}
for col in numeric_columns:
    Q1 = final_data[col].quantile(0.25)
    Q3 = final_data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = final_data[(final_data[col] < lower_bound) | (final_data[col] > upper_bound)]
    outlier_summary[col] = len(outliers)

outlier_summary = {k: v for k, v in outlier_summary.items() if v > 0}
outlier_summary
# Out:
# {'weathersit': 1,
#  'temp': 66,
#  'atemp': 41,
#  'windspeed': 4,
#  'casual': 66,
#  'registered': 45}

# %% [markdown]
# NOTE : so here we deduct some outliers and now we are going to handle these outliers using capping method based on IQR.
#
# 1 - weathersit: 1 outlier,
# 2 - temp: 66 outliers,
# 3 - atemp: 41 outliers,
# 4 - windspeed: 4 outliers,
# 5 - casual: 66 outliers,
# 6 - registered: 45 outliers,
# 7 - cnt: 30 outliers,

# %%
# Handle Outliers using IQR capping

final_data_capped = final_data.copy()

for col in outlier_summary.keys():
    Q1 = final_data[col].quantile(0.25)
    Q3 = final_data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

# %%
final_data_capped
# Out:
#      instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0          1 2011-01-01       1     1   0    False        6           1  0.24
# 1          2 2011-01-01       1     1   1    False        6           1  0.22
# 2          3 2011-01-01       1     1   2    False        6           1  0.22
# 3          4 2011-01-01       1     1   3    False        6           1  0.24
# 4          5 2011-01-01       1     1   4    False        6           1  0.24
# ..       ...        ...     ...   ...  ..      ...      ...         ...   ...
# 995      615 2011-01-28       1     1  20    False        5           2  0.24
# 996      616 2011-01-28       1     1  21    False        5           2  0.22
# 997      617 2011-01-28       1     1  22    False        5           1  0.24
# 998      618 2011-01-28       1     1  23    False        5           1  0.24
# 999      619 2011-01-29       1     1   0    False        6           1  0.22
#
# ...

# %%
# Analyze Skewness of Numerical Columns

numeric_columns = final_data_capped.select_dtypes(include=['float64', 'int64']).columns
skewness = final_data_capped[numeric_columns].apply(lambda x: skew(x.dropna()))

print("Skewness of Numerical Columns:\n", skewness)
# Out:
# Skewness of Numerical Columns:
#  instant       0.000000
# season             NaN
# mnth          0.811552
# hr           -0.063428
# weekday       0.021892
# weathersit    1.042531
# temp          0.547175
# atemp         0.436407
# hum           0.436238
# windspeed     0.433024
# casual        3.408982
# registered    1.294777
# cnt           0.936032
# dtype: float64

# %%
final_data_capped
# Out:
#      instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0          1 2011-01-01       1     1   0    False        6           1  0.24
# 1          2 2011-01-01       1     1   1    False        6           1  0.22
# 2          3 2011-01-01       1     1   2    False        6           1  0.22
# 3          4 2011-01-01       1     1   3    False        6           1  0.24
# 4          5 2011-01-01       1     1   4    False        6           1  0.24
# ..       ...        ...     ...   ...  ..      ...      ...         ...   ...
# 995      615 2011-01-28       1     1  20    False        5           2  0.24
# 996      616 2011-01-28       1     1  21    False        5           2  0.22
# 997      617 2011-01-28       1     1  22    False        5           1  0.24
# 998      618 2011-01-28       1     1  23    False        5           1  0.24
# 999      619 2011-01-29       1     1   0    False        6           1  0.22
#
# ...

# %%
# Step 2: Compute Correlations Between Attributes

correlation_matrix = final_data_capped[numeric_columns].corr()

# %%
correlation_matrix
# Out:
#              instant  season      mnth        hr   weekday  weathersit  \
# instant     1.000000     NaN  0.802477  0.000060  0.008157    0.030439
# season           NaN     NaN       NaN       NaN       NaN         NaN
# mnth        0.802477     NaN  1.000000 -0.025646  0.034710    0.014061
# hr          0.000060     NaN -0.025646  1.000000  0.007531   -0.055802
# weekday     0.008157     NaN  0.034710  0.007531  1.000000    0.060007
# weathersit  0.030439     NaN  0.014061 -0.055802  0.060007    1.000000
# temp        0.023406     NaN  0.159660  0.203512 -0.081776    0.106041
# atemp       0.078216     NaN  0.192487  0.148514 -0.051462    0.136909
# hum         0.062116     NaN  0.066587 -0.194853  0.062469    0.539402
# windspeed  -0.057837     NaN -0.029383  0.116640 -0.056754   -0.177655
# casual      0.071259     NaN  0.088326  0.204476 -0.047363   -0.096346
# registered  0.074993     NaN  0.072660  0.357042  0.020505   -0.119234
# ...

# %%
# Display the correlation matrix

print("Correlation Matrix:\n", correlation_matrix)
# Out:
# Correlation Matrix:
#               instant  season      mnth        hr   weekday  weathersit  \
# instant     1.000000     NaN  0.802477  0.000060  0.008157    0.030439
# season           NaN     NaN       NaN       NaN       NaN         NaN
# mnth        0.802477     NaN  1.000000 -0.025646  0.034710    0.014061
# hr          0.000060     NaN -0.025646  1.000000  0.007531   -0.055802
# weekday     0.008157     NaN  0.034710  0.007531  1.000000    0.060007
# weathersit  0.030439     NaN  0.014061 -0.055802  0.060007    1.000000
# temp        0.023406     NaN  0.159660  0.203512 -0.081776    0.106041
# atemp       0.078216     NaN  0.192487  0.148514 -0.051462    0.136909
# hum         0.062116     NaN  0.066587 -0.194853  0.062469    0.539402
# windspeed  -0.057837     NaN -0.029383  0.116640 -0.056754   -0.177655
# casual      0.071259     NaN  0.088326  0.204476 -0.047363   -0.096346
# registered  0.074993     NaN  0.072660  0.357042  0.020505   -0.119234
# ...

# %% [markdown]
# # Heatmap

# %%
# Now we are Visualizing Insights
# Heatmap for Correlations

plt.figure(figsize=(12, 8))
correlation_matrix = correlation_matrix[['temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='plasma', fmt='.2f', cbar=True)
plt.title('Heatmap of Correlation between Numerical Features')
plt.show()

# %% [markdown]
# The heatmap helps visualize the correlation between numerical variables in the dataset. Here’s how to interpret and summarize insights from the heatmap based on the dataset:
#
# 1. Strong Positive Correlations:
#
# cnt vs registred: High correlation (close to 1), indicating that the majority of bike rentals are made by registered users.
# temp vs atemp: Almost perfect correlation (close to 1), as both variables measure temperature but represent actual and perceived temperatures.
# cnt vs temp/atemp: Positive correlation suggests that bike rentals increase with higher temperatures (people prefer biking in warm weather).
#
# 2. Moderate Positive Correlations:
#
# casual vs temp/atemp: Casual riders are more influenced by weather conditions, with increased rentals on warm days.
# hum vs temp/atemp: Moderate positive correlation, as warmer air holds more moisture, though this relationship can vary by location and season.
#
# 3. Weak or No Correlations:
#
# windspeed vs other variables: Windspeed tends to show a weak or negative correlation with other variables, indicating its minimal influence on bike rentals compared to temperature or humidity.
#
# 4. Negative Correlations:
#
# cnt vs windspeed: A slight negative correlation suggests that higher wind speeds might deter people from biking.
# hum vs cnt: A weak negative correlation may indicate that high humidity slightly reduces bike rentals, as humid conditions might feel uncomfortable.
# Importance of Correlation:
# Understanding Trends:
# High correlations (between cnt and registered) help identify key drivers of bike rentals.
# Weak correlations (with windspeed) indicate less influential factors.
# Feature Selection:
# Features with strong correlations to cnt can be prioritized in predictive models (e.g., temperature, registered users).
# Operational Insights:
#
# Negative correlations (with windspeed) can help operational teams plan better for adverse weather conditions.

# %% [markdown]
# # Scatter Plot

# %%
# Scatter plot: Relationship between temperature and humidity 

# Scatter plot: temp vs. hum
final_data.plot(x='temp',y='hum',kind='scatter',color='magenta',)
plt.title('temp vs hum',fontsize=20)
plt.show()

# %% [markdown]
# Negative Correlation:
#
# There might be a trend where humidity decreases as temperature increases. Warmer air can hold more moisture, but relative humidity tends to drop as the temperature rises.
# Clustering Patterns:
# Observe if there are distinct clusters in the data. For instance: High humidity at low temperatures might indicate cooler, wetter conditions (like early mornings or rainy days).
# Low humidity at higher temperatures could suggest hot and dry conditions.
# Outliers:
# Identify data points that deviate significantly from the general trend, such as unusually high humidity at very high temperatures. These could correspond to specific weather events like heat waves with high humidity.
# Seasonal Influence:
#
# Humidity levels between 30-60% might align with moderate temperatures, showing a region where the weather is perceived as comfortable.
# These insights can help understand the interplay between temperature and humidity, which is useful in weather analysis, planning outdoor events, or predicting demand in weather-sensitive industries.

# %% [markdown]
# # Line Plot

# %%
# Create a line plot
plt.figure(figsize=(7, 6))
sns.lineplot(x='windspeed', y='weathersit', data=final_data, marker='o')

plt.title('windspeed vs weathersituation', fontsize=20)
plt.xlabel('weathersit', fontsize=15)
plt.ylabel('windspeed', fontsize=15)
#plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 7))
sns.lineplot(data=final_data, x='atemp', y='windspeed',)
plt.title('Temperature and windspeed Trend')
plt.xlabel('Temperature')
plt.ylabel('windspeed')
plt.show()

# %% [markdown]
# Inverse Relationship:
#
# You might notice that as windspeed increases, atemp tends to decrease. This reflects the cooling effect of wind, where even on warm days, higher winds can make the temperature feel cooler.
# Periodic Patterns:
# If the data spans multiple days or seasons, you may observe repeating patterns where windspeed peaks coincide with dips in atemp, possibly indicating specific weather conditions (e.g., stormy periods).
# Sudden Variations:
# Sudden spikes in windspeed with corresponding drops in atemp could indicate events like windy or stormy days.
# Plateaus in Windspeed:
# Periods of stable, low windspeed might show a steady or rising trend in atemp, especially during calm, warm weather.
# Correlation:

# %% [markdown]
# # Histplot

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(8,6))
sns.histplot(data=final_data[['cnt','casual','registered']],ax=ax1)
sns.histplot(data=final_data[['temp','windspeed','hum']],ax=ax2)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# NOTE : The provided code generates two subplots with histograms, displaying the distribution of variables from a dataset named final_data. Here's an analysis of the possible insights based on the visualizations it creates:
#
# Plot 1: Distribution of 'cnt', 'casual', and 'registered' (on ax1)
# This plot represents the distribution of three variables:
#
# cnt: Total number of bike rentals.
# casual: Number of casual bike rentals (users who are not registered).
# registered: Number of registered bike rentals (users who are registered).
#
# Central tendency: Observing the histograms of 'cnt', 'casual', and 'registered' will give insight into their central tendencies (mean, median).
#
# Skewness: If the distribution is skewed (either left or right), it indicates the presence of a few extreme values or a potential need for data transformation. For instance, if 'casual' shows a long right tail, it may indicate that there are occasional peaks in casual rentals, such as on weekends or holidays.
#
# Plot 2: Distribution of 'temp', 'windspeed', and 'hum' (on ax2)
# This plot shows the distribution of three weather-related variables:
#
# temp: Temperature (likely in Celsius or Fahrenheit).
# windspeed: Wind speed (likely in km/h or m/s).
# hum: Humidity (likely as a percentage).
#
# Seasonal Effects on Rentals: A high temperature may correlate with more bike rentals (especially casual ones). The distribution of 'temp' can help identify if bike rentals peak in warmer months.
#
# General Insights:
# The relationship between bike rentals and weather conditions can be analyzed.
